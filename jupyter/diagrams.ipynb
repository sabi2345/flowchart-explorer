# %%
from diagrams import Diagram, Node, Edge
from diagrams.programming.flowchart import InputOutput
from diagrams.programming.flowchart import Action

from flowchart_explorer.flowchartdiagrams.nodes import StartEnd, InLoop, Outloop, Decision, Action

graph_attr = {
    "fontsize": "24",
    "labelloc": "t",
    "bgcolor": "ghostwhite"

    
}
with Diagram("FlowChart", show=False, outformat="png", direction="TB", graph_attr=graph_attr) as diag:
    start = StartEnd("Start Node2")
    a1 = Action("Action1だよ")
    d1 = Decision("a < 2")
    in_loop = InLoop("loopid=2\nx <= 3")
    out_loop = Outloop("loopid=2")
    a2 = Action("Action2ですね＝－＝")
    edge1 = Edge(forward=True)
    end = StartEnd("End")
    edge2 = Edge(forward=True)
    edge3 = Edge(forward=True)
    edge4 = Edge(forward=True)
    edge5 = Edge(forward=True)
    edge6 = Edge(forward=True)
    edge7 = Edge(forward=True)
    edge8 = Edge(forward=True)

    start.connect(d1, edge1)
    d1.connect(in_loop, edge2)
    in_loop.connect(a2, edge3)
    a2.connect(out_loop, edge4)
    out_loop.connect(end, edge5)
    
    # StartEnd("Start Node\n I am elegant start",) >> InputOutput("Num1 Num2") >> Action("Sum") >> InputOutput("Print Sum") >> StartEnd("End")

# %%
diag
